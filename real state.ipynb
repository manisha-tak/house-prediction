# %% [markdown]
# # real state price predictor

# %%
import pandas as pd

# %%
housing=pd.read_csv("data.csv.csv")

# %%
housing.head()
# Out:
#       CRIM  RES.LAND  INDUS  CHARIL RIV.    NOX  AVER.ROOM   AGE  DIS EMP.  \
# 0  0.00632      18.0   2.31            0  0.538      6.575  65.2    4.0900
# 1  0.02731       0.0   7.07            0  0.469      6.421  78.9    4.9671
# 2  0.02729       0.0   7.07            0  0.469      7.185  61.1    4.9671
# 3  0.03237       0.0   2.18            0  0.458        NaN  45.8    6.0622
# 4  0.06905       0.0   2.18            0  0.458      7.147  54.2    6.0622
#
#    RAD  TAX  PUBLIC TEACHER RATO  BLACK BY TOWN  LSTAT  MEDIAN VAL
# 0    1  296                 15.3         396.90   4.98        24.0
# 1    2  242                 17.8         396.90   9.14        21.6
# 2    2  242                 17.8         392.83   4.03        34.7
# 3    3  222                 18.7         394.63   2.94        33.4
# 4    3  222                 18.7         396.90   5.33        36.2

# %%
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   CRIM                 506 non-null    float64
#  1   RES.LAND             506 non-null    float64
#  2   INDUS                506 non-null    float64
#  3   CHARIL RIV.          506 non-null    int64
#  4   NOX                  506 non-null    float64
#  5   AVER.ROOM            501 non-null    float64
#  6   AGE                  506 non-null    float64
#  7   DIS EMP.             506 non-null    float64
#  8   RAD                  506 non-null    int64
#  9   TAX                  506 non-null    int64
#  10  PUBLIC TEACHER RATO  506 non-null    float64
#  11  BLACK BY TOWN        506 non-null    float64
#  12  LSTAT                506 non-null    float64
#  13  MEDIAN VAL           506 non-null    float64
# dtypes: float64(11), int64(3)
# memory usage: 55.5 KB

# %%
housing['CHARIL RIV.'].value_counts()
# Out:
# 0    471
# 1     35
# Name: CHARIL RIV., dtype: int64

# %%
housing.describe()
# Out:
#              CRIM    RES.LAND       INDUS  CHARIL RIV.         NOX  \
# count  506.000000  506.000000  506.000000   506.000000  506.000000
# mean     3.613524   11.363636   11.136779     0.069170    0.554695
# std      8.601545   23.322453    6.860353     0.253994    0.115878
# min      0.006320    0.000000    0.460000     0.000000    0.385000
# 25%      0.082045    0.000000    5.190000     0.000000    0.449000
# 50%      0.256510    0.000000    9.690000     0.000000    0.538000
# 75%      3.677083   12.500000   18.100000     0.000000    0.624000
# max     88.976200  100.000000   27.740000     1.000000    0.871000
#
#         AVER.ROOM         AGE    DIS EMP.         RAD         TAX  \
# count  501.000000  506.000000  506.000000  506.000000  506.000000
# mean     6.283796   68.574901    3.795043    9.549407  408.237154
# std      0.705066   28.148861    2.105710    8.707259  168.537116
# min      3.561000    2.900000    1.129600    1.000000  187.000000
# ...

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

# %%
housing.hist(bins=50,figsize=(20,15))
# Out:
# array([[<AxesSubplot:title={'center':'CRIM'}>,
#         <AxesSubplot:title={'center':'RES.LAND'}>,
#         <AxesSubplot:title={'center':'INDUS'}>,
#         <AxesSubplot:title={'center':'CHARIL RIV.'}>],
#        [<AxesSubplot:title={'center':'NOX'}>,
#         <AxesSubplot:title={'center':'AVER.ROOM'}>,
#         <AxesSubplot:title={'center':'AGE'}>,
#         <AxesSubplot:title={'center':'DIS EMP.'}>],
#        [<AxesSubplot:title={'center':'RAD'}>,
#         <AxesSubplot:title={'center':'TAX'}>,
#         <AxesSubplot:title={'center':'PUBLIC TEACHER RATO'}>,
#         <AxesSubplot:title={'center':'BLACK BY TOWN'}>],
#        [<AxesSubplot:title={'center':'LSTAT'}>,
#         <AxesSubplot:title={'center':'MEDIAN VAL'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %% [markdown]
# ## train_test splitting

# %%
#import numpy as np
#for learning purpose

# %%
#def split_train_test(data,test_ratio):
   ## np.random.seed(42)
    ##shuffled=np.random.permutation(len(data))
    ##print(shuffled)
    ##test_set_size=int(len(data)*test_ratio)
    #test_indices=shuffled[:test_set_size]
    #train_indices=shuffled[test_set_size:]
    #return data.iloc[train_indices],data.iloc[test_indices]

# %%
#train_set,test_set=split_train_test(housing,0.2)

# %%
#print(f"row in train set:{len(train_set)}\nrows in test set:{(len(test_set))}\n")

# %%
from sklearn.model_selection import train_test_split
train_set,test_set=train_test_split(housing,test_size=0.2,random_state=42)
print(f"row in train set:{len(train_set)}\nrows in test set:{(len(test_set))}\n")#
# Out:
# row in train set:404
# rows in test set:102

# %%
from sklearn.model_selection import StratifiedShuffleSplit
split= StratifiedShuffleSplit(n_splits=1,test_size=0.2,random_state=42)
for train_index, test_index in split.split(housing, housing['CHARIL RIV.']):
    strat_train_set=housing.loc[train_index]
    strat_test_set= housing.loc[test_index]

# %%
strat_test_set['CHARIL RIV.'].value_counts()
# Out:
# 0    95
# 1     7
# Name: CHARIL RIV., dtype: int64

# %%
strat_train_set['CHARIL RIV.'].value_counts()
# Out:
# 0    376
# 1     28
# Name: CHARIL RIV., dtype: int64

# %% [markdown]
# ## looking for correlation

# %%
corr_matrix=housing.corr()

# %%
corr_matrix['MEDIAN VAL'].sort_values(ascending=False)
# Out:
# MEDIAN VAL             1.000000
# AVER.ROOM              0.694690
# RES.LAND               0.360445
# BLACK BY TOWN          0.333461
# DIS EMP.               0.249929
# CHARIL RIV.            0.175260
# AGE                   -0.376955
# RAD                   -0.381626
# CRIM                  -0.388305
# NOX                   -0.427321
# TAX                   -0.468536
# INDUS                 -0.483725
# PUBLIC TEACHER RATO   -0.507787
# LSTAT                 -0.737663
# Name: MEDIAN VAL, dtype: float64

# %%
from pandas.plotting import scatter_matrix
attributes=["MEDIAN VAL","AVER.ROOM","RES.LAND","LSTAT"]
scatter_matrix(housing[attributes],figsize=(12,8))
# Out:
# array([[<AxesSubplot:xlabel='MEDIAN VAL', ylabel='MEDIAN VAL'>,
#         <AxesSubplot:xlabel='AVER.ROOM', ylabel='MEDIAN VAL'>,
#         <AxesSubplot:xlabel='RES.LAND', ylabel='MEDIAN VAL'>,
#         <AxesSubplot:xlabel='LSTAT', ylabel='MEDIAN VAL'>],
#        [<AxesSubplot:xlabel='MEDIAN VAL', ylabel='AVER.ROOM'>,
#         <AxesSubplot:xlabel='AVER.ROOM', ylabel='AVER.ROOM'>,
#         <AxesSubplot:xlabel='RES.LAND', ylabel='AVER.ROOM'>,
#         <AxesSubplot:xlabel='LSTAT', ylabel='AVER.ROOM'>],
#        [<AxesSubplot:xlabel='MEDIAN VAL', ylabel='RES.LAND'>,
#         <AxesSubplot:xlabel='AVER.ROOM', ylabel='RES.LAND'>,
#         <AxesSubplot:xlabel='RES.LAND', ylabel='RES.LAND'>,
#         <AxesSubplot:xlabel='LSTAT', ylabel='RES.LAND'>],
#        [<AxesSubplot:xlabel='MEDIAN VAL', ylabel='LSTAT'>,
#         <AxesSubplot:xlabel='AVER.ROOM', ylabel='LSTAT'>,
#         <AxesSubplot:xlabel='RES.LAND', ylabel='LSTAT'>,
# ...

# %%
housing.plot(kind="scatter",x="AVER.ROOM",y="MEDIAN VAL", alpha=0.8)
# Out:
# <AxesSubplot:xlabel='AVER.ROOM', ylabel='MEDIAN VAL'>

# %% [markdown]
# # #attribute combination

# %%
housing["TAXRM"]=housing['TAX']/housing['AVER.ROOM']

# %%
housing.head()
# Out:
#       CRIM  RES.LAND  INDUS  CHARIL RIV.    NOX  AVER.ROOM   AGE  DIS EMP.  \
# 0  0.00632      18.0   2.31            0  0.538      6.575  65.2    4.0900
# 1  0.02731       0.0   7.07            0  0.469      6.421  78.9    4.9671
# 2  0.02729       0.0   7.07            0  0.469      7.185  61.1    4.9671
# 3  0.03237       0.0   2.18            0  0.458        NaN  45.8    6.0622
# 4  0.06905       0.0   2.18            0  0.458      7.147  54.2    6.0622
#
#    RAD  TAX  PUBLIC TEACHER RATO  BLACK BY TOWN  LSTAT  MEDIAN VAL      TAXRM
# 0    1  296                 15.3         396.90   4.98        24.0  45.019011
# 1    2  242                 17.8         396.90   9.14        21.6  37.688834
# 2    2  242                 17.8         392.83   4.03        34.7  33.681280
# 3    3  222                 18.7         394.63   2.94        33.4        NaN
# 4    3  222                 18.7         396.90   5.33        36.2  31.061984

# %%
corr_matrix=housing.corr()
corr_matrix['MEDIAN VAL'].sort_values(ascending=False)
# Out:
# MEDIAN VAL             1.000000
# AVER.ROOM              0.694690
# RES.LAND               0.360445
# BLACK BY TOWN          0.333461
# DIS EMP.               0.249929
# CHARIL RIV.            0.175260
# AGE                   -0.376955
# RAD                   -0.381626
# CRIM                  -0.388305
# NOX                   -0.427321
# TAX                   -0.468536
# INDUS                 -0.483725
# PUBLIC TEACHER RATO   -0.507787
# TAXRM                 -0.536832
# LSTAT                 -0.737663
# Name: MEDIAN VAL, dtype: float64

# %%
housing.plot(kind="scatter",x="TAXRM",y="MEDIAN VAL", alpha=0.8)
# Out:
# <AxesSubplot:xlabel='TAXRM', ylabel='MEDIAN VAL'>

# %%
housing=strat_train_set.drop("MEDIAN VAL",axis=1)
housing_labels=strat_train_set["MEDIAN VAL"].copy()

# %%
from sklearn.impute import SimpleImputer
imputer=SimpleImputer(strategy="median")
imputer.fit(housing)
# Out:
# SimpleImputer(strategy='median')

# %%
imputer.statistics_
# Out:
# array([2.86735e-01, 0.00000e+00, 9.90000e+00, 0.00000e+00, 5.38000e-01,
#        6.20900e+00, 7.82000e+01, 3.12220e+00, 5.00000e+00, 3.37000e+02,
#        1.90000e+01, 3.90955e+02, 1.15700e+01])

# %%
x=imputer.transform(housing)

# %%
housing_tr=pd.DataFrame(x,columns=housing.columns)

# %%
housing_tr.describe()
# Out:
#              CRIM    RES.LAND       INDUS  CHARIL RIV.         NOX  \
# count  404.000000  404.000000  404.000000   404.000000  404.000000
# mean     3.602814   10.836634   11.344950     0.069307    0.558064
# std      8.099383   22.150636    6.877817     0.254290    0.116875
# min      0.006320    0.000000    0.740000     0.000000    0.389000
# 25%      0.086962    0.000000    5.190000     0.000000    0.453000
# 50%      0.286735    0.000000    9.900000     0.000000    0.538000
# 75%      3.731923   12.500000   18.100000     0.000000    0.631000
# max     73.534100  100.000000   27.740000     1.000000    0.871000
#
#         AVER.ROOM         AGE    DIS EMP.         RAD         TAX  \
# count  404.000000  404.000000  404.000000  404.000000  404.000000
# mean     6.277938   69.039851    3.746210    9.735149  412.341584
# std      0.711720   28.258248    2.099057    8.731259  168.672623
# min      3.561000    2.900000    1.129600    1.000000  187.000000
# ...

# %% [markdown]
# creating pipeline

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
my_pipeline=Pipeline([
    ('imputer', SimpleImputer(strategy="median")),
    ('std_scaler', StandardScaler())
])

# %%
housing_num_tr=my_pipeline.fit_transform(housing)

# %%
housing_num_tr.shape
# Out:
# (404, 13)

# %% [markdown]
# selecting desired model

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
#model=DecisionTreeRegressor()
model=RandomForestRegressor()
#model=LinearRegression()
model.fit(housing_num_tr,housing_labels)
# Out:
# RandomForestRegressor()

# %%
some_data=housing.iloc[:5]
some_lables=housing_labels.iloc[:5]
prepared_data=my_pipeline.transform(some_data)

# %%
model.predict(prepared_data)
# Out:
# array([22.217, 25.419, 16.365, 23.26 , 23.547])

# %%
list(some_lables)
# Out:
# [21.9, 24.5, 16.7, 23.1, 23.0]

# %% [markdown]
# evaluating the data

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt
housing_prediction=model.predict(housing_num_tr)
lin_mse=mean_squared_error(housing_labels,housing_prediction)
lin_rmse=sqrt(lin_mse)

# %%
lin_mse
# Out:
# 1.4208602896039573

# %%
lin_rmse
# Out:
# 1.191998443624805

# %% [markdown]
# checking for decision tree model

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt
housing_prediction=model.predict(housing_num_tr)
mse=mean_squared_error(housing_labels,housing_prediction)
rmse=sqrt(lin_mse)

# %%
mse
# Out:
# 1.4208602896039573

# %%
rmse
# Out:
# 1.191998443624805

# %% [markdown]
# overfitting happen

# %% [markdown]
# cross validation

# %%
from sklearn.model_selection import cross_val_score
from  math import sqrt
import numpy as np
scores=cross_val_score(model,housing_num_tr,housing_labels,scoring="neg_mean_squared_error",cv=10)
rmse= np.sqrt(-scores)

# %%
rmse
# Out:
# array([2.94688225, 2.83636526, 4.43278523, 2.68524719, 3.17798252,
#        2.576439  , 4.47948665, 3.24179782, 3.03362543, 3.26566094])

# %%
def print_scores(scores):
    print("scores:",scores)
    print("mean:",scores.mean())
    print("Standard div",scores.std())

# %%
print_scores(rmse)
# Out:
# scores: [2.94688225 2.83636526 4.43278523 2.68524719 3.17798252 2.576439
#  4.47948665 3.24179782 3.03362543 3.26566094]
# mean: 3.267627230110013
# Standard div 0.6320943260264152

# %% [markdown]
# for decision tee
# mean: 4.578163660387501
# Standard div 1.4300779651865791

# %% [markdown]
# for linear regressionmean: 5.040529758654507
# Standard div 1.0594812440929453

# %% [markdown]
# for random forest regression mean: 3.3265879600576453
# Standard div 0.6408741530886336

# %% [markdown]
# saving the data file

# %%
from joblib import dump,load
dump(model,'data.joblib')
# Out:
# ['data.joblib']

# %% [markdown]
# testing the data

# %%
x_test=strat_test_set.drop("MEDIAN VAL",axis=1)
y_test=strat_test_set["MEDIAN VAL"].copy()
x_test_prepared=my_pipeline.transform(x_test)
final_predictions=model.predict(x_test_prepared)
final_mse=mean_squared_error(y_test,final_predictions)
final_rmse=np.sqrt(final_mse)
print(final_predictions,list(y_test))
# Out:
# [24.457 11.519 25.314 22.354 18.736 14.681 19.891 14.721 31.231 41.245
#  19.664 11.548 24.05  26.369 19.708 11.126 30.779 14.371 23.404 19.501
#  20.134 17.913 18.327 22.476 19.124 31.505 15.717 33.144  8.834 33.926
#  23.215 21.456 22.769 10.993 21.266 11.78  42.996 24.485 24.108 41.341
#  24.044 29.935 20.456 21.048 18.704 33.08  44.389 20.022 20.147 22.339
#  20.886 14.538 21.306 15.127 24.293 33.327 41.027 28.849 19.757 20.895
#  46.809  9.972 18.79  25.041 14.836 33.718 19.607 18.079 19.261 34.459
#  25.474 22.852 21.788 22.434 34.965 12.681 15.794 20.346 20.79  21.82
#  22.111 21.102 13.495 22.848 20.494 21.22  14.242 21.526 21.434 23.195
#  18.419 27.198  7.372 26.205 18.715 28.666 19.834 31.133 14.711 26.986
# ...

# %%
final_rmse
# Out:
# 2.953708436764156

# %%
prepared_data[0]
# Out:
# array([-0.43942006,  3.12628155, -1.12165014, -0.27288841, -1.42262747,
#        -0.23906714, -1.31238772,  2.61111401, -1.0016859 , -0.5778192 ,
#        -0.97491834,  0.41164221, -0.86091034])

# %% [markdown]
# using the model

# %%
from joblib import dump ,load
import numpy as np
model=load('data.joblib')

# %%
features=np.array([[-0.43942006,  3.12628155, -1.12165014, -0.27288841, -1.42262747,
       -0.23906714, -1.31238772,  2.61111401, -1.0016859 , -0.5778192 ,
       -0.97491834,  0.41164221, -0.86091034]])
model.predict(features)
# Out:
# array([22.428])
